# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
P_A=1/4
P_B=1/3
P_AUB=23/60
P_AB=P_A + P_B -P_AUB
P_AlB=P_AB/P_B
print('P(A|B)=',P_AlB)
print('P[(A∩B)|B]=',P_AB/P_B)
print('P[(A∩B\u0305)|B]=',0/P_B)
print('P[(AUB)|(A∩B\u0305)]=',(P_A-P_AB)/(P_A-P_AB))
print('P[(A∩B̅)|B̅]=',(P_A-P_AB)/(1-P_B))
# Out:
# P(A|B)= 0.5999999999999998
# P[(A∩B)|B]= 0.5999999999999998
# P[(A∩B̅)|B]= 0.0
# P[(AUB)|(A∩B̅)]= 1.0
# P[(A∩B̅)|B̅]= 0.07500000000000014
