# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#1
P_A=1/2
P_B=1/2
P_a_b=1/3
print(f'P(A\u0305∪B\u0305) = P(A\u0305) + P(B\u0305) - P(A\u0305∩B\u0305) = 1/2 + 1/2 - 1/3 = {(1-P_A)+(1-P_B) - P_a_b}')
# Out:
# P(A̅∪B̅) = P(A̅) + P(B̅) - P(A̅∩B̅) = 1/2 + 1/2 - 1/3 = 0.6666666666666667

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#2
P_B=0.4
P_AlB=0.25
P_blA=0.5

P_AB = P_B * P_AlB
print(f'P(A) = {P_AB/(P_blA*(1/P_blA-1))} ')
# Out:
# P(A) = 0.2

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#3
P_A = 0.25
P_B=0.35
P_AUB=P_A+P_B - P_A*P_B
print('P(A∪B)=',P_AUB)
# Out:
# P(A∪B)= 0.5125

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#4
P_FlA=0.35
P_FlB=0.24
P_FlC=0.45
P_AF=0.07
P_A = P_AF/P_FlA
P_C=(1-P_A)/8
P_B=7*P_C
P_F = P_A*P_FlA +P_B*P_FlB + P_C*P_FlC
print('P(F) =',P_F)
# Out:
# P(F) = 0.283

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
P_FLA=0.25
P_FLB=0.35
P_FlB=0.15
P_C=1/5
P_B=P_A=2*P_C
P_F=P_A*P_FlA +P_B*P_FlB + P_C*P_FlC
print('P(F)=',P_F)
# Out:
# P(F)= 0.29

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
P_A=0.4
P_AUB=0.6
P_B=(P_AUB-P_A)/(1-P_A)
print('P(B)=',P_B)
# Out:
# P(B)= 0.33333333333333326

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
P_BlA1=0.5
P_BlA2=0.25
P_A1=P_A2=0.5
P_B=P_BlA1*P_A1+P_BlA2*P_BlA2
P_A1B=P_BlA1*P_A1
p_A1lB=P_A1B*P_B
print('P(A1|B)=',p_A1lB)
# Out:
# P(A1|B)= 0.078125
