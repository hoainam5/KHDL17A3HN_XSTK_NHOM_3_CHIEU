# %% [markdown]
# ![Screenshot 2024-05-26 231411.png](data:image/png;base64,...)

# %%
n_Y = 2
p_Y = 0.6
N_Z = 10
M_Z = 6
n_Z = 3/100
E_X = 12
D_X = 25
mod_X = 12
mod_Y = 1
E_Y = n_Y * p_Y
E_Z = (n_Z*M_Z)/N_Z
E_U = E_X*E_Y+D_X*E_Z - mod_X*mod_Y
print("1a. kỳ vọng của biến ngẫu nhiên X,Y,Z là:", E_U)
#D_U=E(X)**2 *D(Y)+D(X)*D(Z)
D_Y = n_Y*p_Y*(1-p_Y)
D_Z = n_Z*(M_Z/N_Z)*((N_Z-M_Z)/N_Z)*((N_Z-n_Z)/(N_Z-1))
D_U = ((E_X)**2*D_Y)+(D_X*D_Z)
print("1b. phương sai của biến ngẫu nhiên X,Y,Z là:", D_U)
#2) Tính xác suất P(Y = Z)
P_Y0 = 0.16
P_Y1 = 0.48
P_Y2 = 0.36
P_Z0 = 1/30
P_Z1 = 3/10
P_Z2 = 0.5
P_YZ = (P_Y0*P_Z0)+(P_Y1*P_Z1)+(P_Y2*P_Z2)
print("2. P(X=Y) là:", P_YZ)
# Out:
# 1a. kỳ vọng của biến ngẫu nhiên X,Y,Z là: 2.849999999999998
# 1b. phương sai của biến ngẫu nhiên X,Y,Z là: 69.3194
# 2. P(X=Y) là: 0.3293333333333333
