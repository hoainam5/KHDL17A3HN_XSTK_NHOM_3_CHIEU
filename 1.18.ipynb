# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
p_A1=1/6     # A1 là biến cố "Lấy ra từ máy 1"
p_A2=1/3     # A2 là biến cố "Lấy ra từ máy 2"
p_A3=1/2     # A3 là biến cố "Lấy ra từ máy 3"
p_A_A1=0.05  # Xác suất lấy được phế phẩm trong máy 1
p_A_A2=0.06  # Xác suất lấy được phế phẩm trong máy 2
p_A_A3=0.07  # Xác suất lấy được phế phẩm trong máy 3
p_A=p_A1*p_A_A1+p_A2*p_A_A2+p_A3*p_A_A3
p_A3_A=(p_A3*p_A_A3)/p_A
print("Xác suất lấy được phế phẩm ở máy 3 là: ", p_A3_A)
