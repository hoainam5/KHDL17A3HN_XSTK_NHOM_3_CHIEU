# %% [markdown]
# ![Ảnh chụp màn hình 2024-05-15 211913.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
P_A=0.09
P_B=0.12
P_AB=0.07
P_AUB=P_A+P_B-P_AB
print('xác suất bị bệnh tim hay bệnh huyết áp là:',P_AUB)
# Out:
# xác suất bị bệnh tim hay bệnh huyết áp là: 0.13999999999999999

# %%
P_ab=1-P_AUB
print('xác suất không bị bệnh tim cũng như không bị bệnh huyết áp:',P_ab)
# Out:
# xác suất không bị bệnh tim cũng như không bị bệnh huyết áp: 0.86

# %%
P_aUb = 1-P_AB
print('xác suất không bị bệnh tim hay không bị bệnh huyết áp:',P_aUb)
# Out:
# xác suất không bị bệnh tim hay không bị bệnh huyết áp: 0.9299999999999999

# %%
P_Ab=P_A-P_AB
print('xác suất bị bệnh tim nhưng không bị bệnh huyết áp:',P_Ab)
# Out:
# xác suất bị bệnh tim nhưng không bị bệnh huyết áp: 0.01999999999999999

# %%
P_aB = P_B-P_AB
print('xác suất không bị bệnh tim nhưng bị bệnh huyết áp: ',P_aB)
# Out:
# xác suất không bị bệnh tim nhưng bị bệnh huyết áp:  0.04999999999999999
