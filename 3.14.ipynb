# %% [markdown]
# ![Screenshot 2024-05-26 235727.png](data:image/png;base64,...)

# %%
p1 = 0.65
p2 = 0.08
z1 = -0.385
z2 = 1.405
#giải hệ pt
tgian_tb = 22.15
do_lech_chuan = 5.59
print("1a. thời gian trung bình từ nhà đến trường là:", tgian_tb)
print("1b. độ lệch chuẩn của thời gian đi từ nhà đến trường là:", do_lech_chuan)
#P(X>=25)= 1-P(X<=25)
p = 0.305
ty_le = 0.305 * 100
print("2. tỉ lệ học sinh đi học muộn là khoảng:", ty_le,"%")
# Out:
# 1a. thời gian trung bình từ nhà đến trường là: 22.15
# 1b. độ lệch chuẩn của thời gian đi từ nhà đến trường là: 5.59
# 2. tỉ lệ học sinh đi học muộn là khoảng: 30.5 %
