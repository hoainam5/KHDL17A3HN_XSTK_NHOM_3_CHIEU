# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#a
lamba_number = 1
e = 2.7

min_y = int(input("nhap gia tri min_y trong P(min_y <Y < max_y):"))
max_y = int(input("nhap gia tri max_y trong P(min_y<Y<max_y):"))
min_x = (min_y/2)**0.5
max_x = (max_y/2)**0.5
dx = -e**(- max_x) - (- e**(-min_x))
print(dx)
#2
#P(Y<4)=P(-2**0.5<X<2**0.5)=P(0<X<2**0.5)
#F(2**0.5)-F(0)
e=2.718
print(f'P(Y<4) = {e**(-2**0.5)}')
# Out:
# nhap gia tri min_y trong P(min_y <Y < max_y):2
# nhap gia tri max_y trong P(min_y<Y<max_y):18
# 0.3195651069450795
# P(Y<4) = 0.2431523856685837
