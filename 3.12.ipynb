# %% [markdown]
# ![Screenshot 2024-05-26 234350.png](data:image/png;base64,...)

# %%
N_X = 25
M_X = 2
n_X = 10
#P(X<=1)
P_X0 = 0.35
P_X1 = 0.5
p = P_X0+P_X1
pp_nhi_thuc_B = (8,0.85)
#P(Y>=7)=P(Y=7) + P(Y=8)
P_Y7 = 0.385
P_Y8 = 0.2725
P_7a = P_Y7+P_Y8    #xs ít nhất 7 lần trên 1 ngày P(Y>=7)
print("1. xác suất quá trình sx đc báo cáo đạt y/cau ít nhất 7 lần một ngày 8 giờ là xấp xỉ: ", P_7a)
lambda_ = 6.8
#P(X>=7)= 1 - P(X<=6)
P6 = 0.4788
P_7b = 1-P6
print("2. xác suất quá trình sx đc báo cáo đạt y/cau ít nhất 7 lần một ngày 8 giờ là xấp xỉ: ",P_7b)
#P(X=0 | X<=1) = P(X=0)/P(X<=1)
P= 0.412
print("3. xác suất mẫu 10 sp tương ứng không chứa thứ phẩm là:",P)
# Out:
# 1. xác suất quá trình sx đc báo cáo đạt y/cau ít nhất 7 lần một ngày 8 giờ là xấp xỉ:  0.6575
# 2. xác suất quá trình sx đc báo cáo đạt y/cau ít nhất 7 lần một ngày 8 giờ là xấp xỉ:  0.5212
# 3. xác suất mẫu 10 sp tương ứng không chứa thứ phẩm là: 0.412
