# %% [markdown]
# ![Screenshot 2024-05-26 234006.png](data:image/png;base64,...)

# %%
lambda_ = 10000
pp_chuan_N = (10000,10000)
#P(X>20000)
Z = 100      #gtri cực lớn trong pp chuẩn, P(Z>100) gần như bằng 0
print("1. xác suất để có hơn 20000 lượt truy cập mỗi ngày rất nhỏ, xấp xỉ bằng 0")
#P(Z<9900)
b = -1
P = 0.1587
print("2. xác suất để ít hơn 9900 lượt truy cập mỗi ngày xấp xỉ là :", P)
#P(Z>Z_0) = 0.01
Z_0 = 2.33   #tra bảng phân phối chuẩn
x = 10233
print("3. với giá trị mà với xs 0.01 thì có lượt truy cập mỗi ngày vượt quá gtri là: ", x)
# Out:
# 1. xác suất để có hơn 20000 lượt truy cập mỗi ngày rất nhỏ, xấp xỉ bằng 0
# 2. xác suất để ít hơn 9900 lượt truy cập mỗi ngày xấp xỉ là : 0.1587
# 3. với giá trị mà với xs 0.01 thì có lượt truy cập mỗi ngày vượt quá gtri là:  10233
